# %%
using Plots

# %%
colgen = [1.27,0.011,0.008,0.011,0.032,0.033,0.042,0.075,
0.081,0.088,0.112,0.16,0.178,0.202,0.306,0.486,
0.62,0.447,0.634,0.701,0.992,2.359,5.303,6.436,
5.28,26.54,16.461,27.191,51.762,32.941,130.584,419.626];

# %%
sp = [0.444,0.008,0.01,0.011,0.013,0.04,0.093,0.083,
0.115,0.214,0.648,0.831,1.031,1.477,1.763,4.338,
5.381,6.463,9.004,12.962,22.753,36.105,91.770,118.642,
161.885,582.224];

# %%
df = [2.403,2.183,3.383,4.764,7.856,13.054,17.597,19.650,
22.728,27.382,39.908,94.059,75.200,98.522,120.739,212.772,
206.889,381.206,271.587,591.434];

# %%
plot([i for i in 10:41], colgen, label="cg", title="Time Taken with DF, SP, CG", legend=:topleft)
plot!([i for i in 10:35], sp, label="sp")
plot!([i for i in 10:29], df, label="df")
xlabel!("Number of Jobs")
ylabel!("Seconds Taken")

# %%
savefig("time-taken-big-3.png")
# Out:
# "/Users/universe/Documents/MIT/UROP/orc/time-taken-big-3.png"
